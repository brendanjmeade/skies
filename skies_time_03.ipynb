# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = "retina"

# %%
import addict
import datetime
import os
import pickle
import scipy
import colorcet as cc
import matplotlib.pyplot as plt
import numpy as np
from importlib import reload

import skies

# %%
run_name = datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
base_runs_folder = "./runs/"
output_path = os.path.join(base_runs_folder, run_name)
mesh_parameters_file_name = "western_north_america_mesh_parameters.json"
skies.create_output_folder(base_runs_folder, output_path)
meshes = skies.read_meshes(mesh_parameters_file_name)
skies.print_magnitude_overview(meshes)
# Out:
# output_path='./runs/2022_10_31_12_40_36'
# Read: western_north_america_mesh_parameters.json
# Warning: The file contains tag data that couldn't be processed.
# Read: cascadia.msh
# Magnitude overview:
# Maximum moment magnitude of entire mesh = 10.61
# Maximum moment magnitude of single mesh element = 6.90
# Minimum moment magnitude of single mesh element = 5.52

# %%
# Load initial slip defict and multiply by time cascadia_low_resolution_tde_dip_slip_rates.npy
initial_dip_slip_deficit = np.load("cascadia_low_resolution_tde_dip_slip_rates.npy")
total_coseismic_slip = np.zeros_like(initial_dip_slip_deficit)
skies.plot_initial_data(meshes, initial_dip_slip_deficit)

# %%
np.random.seed(1)


def get_omori_decay_probability(time_vector, time_of_earthquake, amplitude, decay_time):
    omori_decay_probability = amplitude / (
        1 + (1 / decay_time) * (time_vector - time_of_earthquake)
    )
    omori_decay_probability[time_vector < time_of_earthquake] = 0.0
    return omori_decay_probability


MM2M = 1e-3  # millimeters to meters
SECONDS_IN_A_YEAR = 60 * 60 * 24 * 365
DAYS_IN_A_YEAR = 365
n_years = 1000

time_vector = np.linspace(0, n_years, n_years * 1)
print(f"{time_vector.shape}")
minimum_probability = 1e-5
time_probability_weight = np.zeros_like(time_vector)
time_event = np.zeros_like(time_vector)
time_magnitude = np.zeros_like(time_vector)
time_probability = np.zeros_like(time_vector)
time_probability = minimum_probability * np.ones_like(time_vector)
new_time_probability = np.zeros_like(time_vector)
new_time_probability_asdf = np.zeros_like(time_vector)


# loading_rate = 30.0  # (mm/yr)
earthquake_index_list = []
earthquake_magnitude_list = []
earthquake_probability_list = []
event_trigger_list = []

b_value = -1.0
minimum_event_moment_magnitude = 5.0
maximum_event_moment_magnitude = 9.0

amplitude = 1e1

# Intial geometric moment and storage
mesh_geometric_moment = 1e-7 * initial_dip_slip_deficit * meshes[0].areas
pre_event_mesh_geometric_moment = np.copy(mesh_geometric_moment)

post_event_mesh_geometric_moment = np.zeros_like(mesh_geometric_moment)
mesh_geometric_moment_scalar = np.zeros_like(time_vector)
mesh_geometric_moment_scalar_non_zero = np.zeros_like(time_vector)
mesh_geometric_moment_scalar[0] = np.sum(initial_dip_slip_deficit * meshes[0].areas)

time_step = 5e-7
interseismic_loading_rate = 5e1 * initial_dip_slip_deficit
time_probability_step = 0.00005
time_probability_step = 1e-15


def get_geometric_moment_condition(event_geometric_moment, mesh_geometric_moment):
    # Case 1: Average geometric moment is grearter than zero
    if np.sum(mesh_geometric_moment) > 0:
        geometric_moment_condition = True
    else:
        geometric_moment_condition = False

    # Case 2: Accumulated geometric moment greater than or equal to

    # if event_geometric_moment < np.sum(
    #     mesh_geometric_moment[np.where(mesh_geometric_moment > 0.0)]
    # ):
    #     geometric_moment_condition = True
    #     # print(f"{event_geometric_moment[0]:0.2e}")
    #     # print(f"{np.sum(mesh_geometric_moment[np.where(mesh_geometric_moment > 0.0)]):0.2e}")
    # else:
    #     geometric_moment_condition = False
    return geometric_moment_condition


def get_tanh_probability(x, amplitude_scale_factor, data_scale_factor):
    tanh_probability = amplitude_scale_factor * np.tanh(data_scale_factor * x)
    if tanh_probability < 0:
        tanh_probability = 0
    if tanh_probability > 1:
        tanh_probability = 1
    return tanh_probability


def get_tanh_probability_vector(x, amplitude_scale_factor, data_scale_factor):
    # TODO: Fix to deal with cases where Nan's appear
    tanh_probability = amplitude_scale_factor * np.tanh(data_scale_factor * x)
    # print(np.sum(np.isfinite(tanh_probability)))
    tanh_probability[np.where(x < 0.0)] = 0.0
    # print(np.sum(np.isfinite(tanh_probability)))
    # tanh_probability[np.where(tanh_probability > 1.0)] = 1.0
    tanh_probability -= np.min(tanh_probability)
    # print(np.sum(np.isfinite(tanh_probability)))
    tanh_probability[np.isnan(tanh_probability)] = 0.0
    # print(np.sum(np.isfinite(tanh_probability)))
    tanh_probability = tanh_probability / np.sum(tanh_probability)
    # print(np.sum(np.isfinite(tanh_probability)))
    return tanh_probability

# Parameters for model run
params = addict.Dict()
params.time_probability_amplitude_scale_factor = 1.0
params.time_probability_data_scale_factor = 1.0
params.location_probability_amplitude_scale_factor = 1.0
params.location_probability_data_scale_factor = 1e-5
params.omori_amplitude_scale_factor = 1e-21
params.omori_rate_perturbation_scale_factor = 1e-1

# Main time loop
for i in range(0, len(time_vector) - 1):

    # Determine whether there is an event at this time step
    time_probability_weight[i] = get_tanh_probability(
        new_time_probability[i],
        params.time_probability_amplitude_scale_factor,
        params.time_probability_data_scale_factor,
    )
    event_trigger = np.random.choice(
        2, 1, p=[1 - time_probability_weight[i], time_probability_weight[i]]
    )
    event_trigger_list.append(event_trigger)
    if event_trigger == 1:
        event = addict.Dict()
        event.shear_modulus = np.array([3e10])
        event.area_scaling = 1.25
        event.moment_magnitude = skies.get_gutenberg_richter_magnitude(
            b_value, minimum_event_moment_magnitude, maximum_event_moment_magnitude
        )
        event.moment = skies.moment_magnitude_to_moment(event.moment_magnitude)
        event.geometric_moment = event.moment / event.shear_modulus
        geometric_moment_condition = get_geometric_moment_condition(
            event.geometric_moment, mesh_geometric_moment
        )
        # if geometric_moment_condition:
        if True:
            print(f"geometric moment condition is True at i={i}")
            time_event[i] = 1.0
            time_magnitude[i] = event.moment_magnitude[0]

            # Find event hypocentral triangle
            event.location_probability = get_tanh_probability_vector(
                pre_event_mesh_geometric_moment,
                params.location_probability_amplitude_scale_factor,
                params.location_probability_data_scale_factor,
            )
            event.hypocenter_triangle_index = np.random.choice(
                meshes[0].n_tde, 1, p=event.location_probability
            )[0]

            # Generate coseismic slip area and slip distribution
            event = skies.get_event_area_slip_triangle_index(meshes[0], event)
            event.pre_event_mesh_geometric_moment = np.copy(
                pre_event_mesh_geometric_moment
            )
            event.post_event_mesh_geometric_moment = np.copy(
                pre_event_mesh_geometric_moment
                - (event.slip_all_elements * meshes[0].areas)
            )

            earthquake_magnitude_list.append(event.moment_magnitude)
            earthquake_index_list.append(i)

            # Generate Omori rate decay
            amplitude = params.omori_amplitude_scale_factor * event.moment
            omori_rate_perturbation = get_omori_decay_probability(
                time_vector, time_vector[i], amplitude, decay_time=20.0
            )

            # Coseismic offset to Omori rate effect
            omori_rate_perturbation[np.where(time_vector > time_vector[i])] -= (
                amplitude * params.omori_rate_perturbation_scale_factor
            )

            # Store Omori rate decay
            earthquake_probability_list.append(omori_rate_perturbation)

            # Subtract event from the geometric moment mesh
            mesh_geometric_moment -= event.slip_all_elements * meshes[0].areas

            # Plot event
            # skies.plot_event(
            #     event,
            #     meshes,
            #     event.pre_event_mesh_geometric_moment,
            #     event.location_probability,
            #     event.post_event_mesh_geometric_moment,
            #     i,
            #     i,
            # )

            # Save event dictionary as pickle file
            event_pickle_file_name = f"{output_path}/event_{i:010.0f}.pickle"
            with open(event_pickle_file_name, "wb") as pickle_file:
                pickle.dump(event, pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

    # Update mesh_geometric_moment
    mesh_geometric_moment += time_step * interseismic_loading_rate * meshes[0].areas
    mesh_geometric_moment_scalar[i + 1] = np.sum(mesh_geometric_moment)
    mesh_geometric_moment_scalar_non_zero[i + 1] = np.sum(
        mesh_geometric_moment[np.where(mesh_geometric_moment > 0.0)]
    )

    # Pre-event moment for next time step
    pre_event_mesh_geometric_moment = np.copy(mesh_geometric_moment)

    # Update probability
    new_time_probability[i + 1] = mesh_geometric_moment_scalar_non_zero[i + 1]
    new_time_probability_asdf[i + 1] = np.copy(new_time_probability[i + 1])

    # Sum contribution from all past earthquakes
    # TODO: The scaling factor here is magic
    for j in range(len(earthquake_index_list)):
        new_time_probability[i + 1] += 1e11 * earthquake_probability_list[j][i + 1]
# Out:
# (1000,)
# geometric moment condition is True at i=1
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=2
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=3
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=4
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=5
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=6
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=7
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=8
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=9
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=10
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=11
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=12
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=13
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=14
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=15
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=16
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=17
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=18
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=19
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=20
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=21
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=22
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=23
# geometric moment condition is True at i=24
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=25
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=26
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=27
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=28
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=29
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=30
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=31
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=32
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=33
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=34
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=35
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=36
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=37
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=38
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=39
# geometric moment condition is True at i=40
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=41
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=42
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=43
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=44
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=45
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=46
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=47
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=48
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=49
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=50
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=51
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=52
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=53
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=54
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=55
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=56
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=57
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=58
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=59
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=60
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=61
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=62
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=63
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=64
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=65
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=66
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=67
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=68
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=69
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=70
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=71
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=72
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=73
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=74
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=75
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=76
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=77
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=78
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=79
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=80
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=81
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=82
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=83
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=84
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=85
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=86
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=87
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=88
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=89
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=90
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=91
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=92
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=93
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=94
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=95
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=96
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=97
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=98
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=99
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=100
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=101
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=102
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=103
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=104
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=105
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=106
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=107
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=108
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=109
# geometric moment condition is True at i=110
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=111
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=112
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=113
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=114
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=115
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=116
# geometric moment condition is True at i=117
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=118
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=119
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=120
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=121
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=122
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=123
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=124
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=125
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=126
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=127
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=128
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=129
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=130
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=131
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=132
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=133
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=134
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=135
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=136
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=137
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=138
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=139
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=140
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=141
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=142
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=143
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=144
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=145
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=146
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=147
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=148
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=149
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=150
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=151
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=152
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=153
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=154
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=155
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=156
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=157
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=158
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=159
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=160
# geometric moment condition is True at i=161
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=162
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=163
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=164
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=165
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=166
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=167
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=168
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=169
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=170
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=171
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=172
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=173
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=174
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=175
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=176
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=177
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=178
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=179
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=180
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=181
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=182
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=183
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=184
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=185
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=186
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=187
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=188
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=189
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=190
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=191
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=192
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=193
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=194
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=195
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=196
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=197
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=198
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=199
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=200
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=201
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=202
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=203
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=204
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=205
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=206
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=207
# geometric moment condition is True at i=208
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=209
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=210
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=211
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=212
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=213
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=214
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=215
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=216
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=217
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=218
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=219
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=220
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=221
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=222
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=223
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=224
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=225
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=226
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=227
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=228
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=229
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=230
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=231
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=232
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=233
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=234
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=235
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=236
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=237
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=238
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=239
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=240
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=241
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=242
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=243
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=244
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=245
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=246
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=247
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=248
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=249
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=250
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=251
# geometric moment condition is True at i=252
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=253
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=254
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=255
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=256
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=257
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=258
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=259
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=260
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=261
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=262
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=263
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=264
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=265
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=266
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=267
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=268
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=269
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=270
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=271
# geometric moment condition is True at i=272
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=273
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=274
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=275
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=276
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=277
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=278
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=279
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=280
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=281
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=282
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=283
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=284
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=285
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=286
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=287
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=288
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=289
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=290
# geometric moment condition is True at i=291
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=292
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=293
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=294
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=295
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=296
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=297
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=298
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=299
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=300
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=301
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=302
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=303
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=304
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=305
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=306
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=307
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=308
# geometric moment condition is True at i=309
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=310
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=311
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=312
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=313
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=314
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=315
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=316
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=317
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=318
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=319
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=320
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=321
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=322
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=323
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=324
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=325
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=326
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=327
# geometric moment condition is True at i=328
# geometric moment condition is True at i=329
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=330
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=331
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=332
# geometric moment condition is True at i=333
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=334
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=335
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=336
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=337
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=338
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=339
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=340
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=341
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=342
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=343
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=344
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=345
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=346
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=347
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=348
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=349
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=350
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=351
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=352
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=353
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=354
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=355
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=356
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=357
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=358
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=359
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=360
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=361
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=362
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=363
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=364
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=365
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=366
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=367
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=368
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=369
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=370
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=371
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=372
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=373
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=374
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=375
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=376
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=377
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=378
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=379
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=380
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=381
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=382
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=383
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=384
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=385
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=386
# geometric moment condition is True at i=387
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=388
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=389
# geometric moment condition is True at i=390
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=391
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=392
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=393
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=394
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=395
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=396
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=397
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=398
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=399
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=400
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=401
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=402
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=403
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=404
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=405
# geometric moment condition is True at i=406
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=407
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=408
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=409
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=410
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=411
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=412
# geometric moment condition is True at i=413
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=414
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=415
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=416
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=417
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=418
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=419
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=420
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=421
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=422
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=423
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=424
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=425
# geometric moment condition is True at i=426
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=427
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=428
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=429
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=430
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=431
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=432
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=433
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=434
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=435
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=436
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=437
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=438
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=439
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=440
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=441
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=442
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=443
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=444
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=445
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=446
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=447
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=448
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=449
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=450
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=451
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=452
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=453
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=454
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=455
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=456
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=457
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=458
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=459
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=460
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=461
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=462
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=463
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=464
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=465
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=466
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=467
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=468
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=469
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=470
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=471
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=472
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=473
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=474
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=475
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=476
# geometric moment condition is True at i=477
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=478
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=479
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=480
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=481
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=482
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=483
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=484
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=485
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=486
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=487
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=488
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=489
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=490
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=491
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=492
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=493
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=494
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=495
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=496
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=497
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=498
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=499
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=500
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=501
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=502
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=503
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=504
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=505
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=506
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=507
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=508
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=509
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=510
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=511
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=512
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=513
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=514
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=515
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=516
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=517
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=518
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=519
# geometric moment condition is True at i=520
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=521
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=522
# Target area is less than hypocenter triangle area
# ...
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=826
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=827
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=828
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=829
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=830
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=831
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=832
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=833
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=834
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=835
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=836
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=837
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=838
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=839
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=840
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=841
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=842
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=843
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=844
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=845
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=846
# geometric moment condition is True at i=847
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=848
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=849
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=850
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=851
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=852
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=853
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=854
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=855
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=856
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=857
# geometric moment condition is True at i=858
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=859
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=860
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=861
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=862
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=863
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=864
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=865
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=866
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=867
# geometric moment condition is True at i=868
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=869
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=870
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=871
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=872
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=873
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=874
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=875
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=876
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=877
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=878
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=879
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=880
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=881
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=882
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=883
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=884
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=885
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=886
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=887
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=888
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=889
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=890
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=891
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=892
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=893
# geometric moment condition is True at i=894
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=895
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=896
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=897
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=898
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=899
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=900
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=901
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=902
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=903
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=904
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=905
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=906
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=907
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=908
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=909
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=910
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=911
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=912
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=913
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=914
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=915
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=916
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=917
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=918
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=919
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=920
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=921
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=922
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=923
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=924
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=925
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=926
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=927
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=928
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=929
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=930
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=931
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=932
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=933
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=934
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=935
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=936
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=937
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=938
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=939
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=940
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=941
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=942
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=943
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=944
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=945
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=946
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=947
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=948
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=949
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=950
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=951
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=952
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=953
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=954
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=955
# geometric moment condition is True at i=956
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=957
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=958
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=959
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=960
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=961
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=962
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=963
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=964
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=965
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=966
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=967
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=968
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=969
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=970
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=971
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=972
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=973
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=974
# geometric moment condition is True at i=975
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=976
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=977
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=978
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=979
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=980
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=981
# geometric moment condition is True at i=982
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=983
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=984
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=985
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=986
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=987
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=988
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=989
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=990
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=991
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=992
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=993
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=994
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=995
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=996
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=997
# Target area is less than hypocenter triangle area
# geometric moment condition is True at i=998
# Target area is less than hypocenter triangle area

# %%
start_idx = 1
end_idx = 400000
end_idx = time_vector.size
figsize = (15, 3)

plt.figure(figsize=figsize)
plt.plot(
    time_vector[start_idx:end_idx],
    mesh_geometric_moment_scalar[start_idx:end_idx],
    "-r",
    linewidth=0.5,
)
plt.xlabel("time index")
plt.ylabel("$\hat{m}$")

# Probability evolution
plt.figure(figsize=figsize)
plt.plot(
    time_vector[start_idx:end_idx],
    new_time_probability[start_idx:end_idx],
    "-k",
    linewidth=0.5,
)
plt.plot([time_vector[start_idx], time_vector[end_idx-1]], [0, 0], "-k", linewidth=0.5)
plt.fill_between(
    time_vector[start_idx:end_idx],
    new_time_probability[start_idx:end_idx],
    np.zeros_like(time_vector[start_idx:end_idx]),
    new_time_probability[start_idx:end_idx] > 0,
    color="orangered",
    alpha=1.0,
    edgecolor=None,
)

plt.fill_between(
    time_vector[start_idx:end_idx],
    new_time_probability[start_idx:end_idx],
    np.zeros_like(time_vector[start_idx:end_idx]),
    new_time_probability[start_idx:end_idx] < 0,
    color="dodgerblue",
    alpha=1.0,
    edgecolor=None,
)
plt.xlim([start_idx, end_idx])
plt.xlabel("time index")
plt.ylabel("$p^t$")

plt.figure(figsize=figsize)
plt.plot(
    time_vector[start_idx:end_idx],
    new_time_probability_asdf[start_idx:end_idx],
    "-r",
    linewidth=0.5,
)
plt.xlabel("time index")
plt.ylabel("$p^t$ asdf")

plt.figure(figsize=figsize)
plt.plot(
    time_vector[start_idx:end_idx],
    time_magnitude[start_idx:end_idx],
    ".r",
    linewidth=0.5, markersize=2,
)
plt.ylim([4.0, 9.1])
plt.xlabel("time index")
plt.ylabel("magnitude")
plt.show()

# %%
# Probability in time: Semilogy plot
plt.figure(figsize=(10, 3))
plt.semilogy(time_vector, time_probability, "-k", linewidth=0.5, zorder=35)
fill_x = np.append(time_vector, np.array([np.max(time_vector), 0]))
fill_y = np.append(
    time_probability, np.array([minimum_probability, minimum_probability])
)
plt.fill(
    fill_x,
    fill_y,
    color="lightsteelblue",
    alpha=1.0,
    edgecolor=None,
    zorder=10,
)

cmap = cc.cm.CET_L17
magnitude_plot_size = 1e-5 * 10 ** np.array(earthquake_magnitude_list)
plt.scatter(
    time_vector[earthquake_index_list],
    time_probability[earthquake_index_list],
    s=magnitude_plot_size,
    c=earthquake_magnitude_list,
    zorder=20,
    alpha=0.65,
    cmap=cmap,
    edgecolors=None,
    linewidths=0.25,
    vmin=6.0,
    vmax=9.0,
)
cb = plt.colorbar(
    cax=plt.gca().inset_axes((0.02, 0.94, 0.15, 0.03)),
    label="magnitude",
    orientation="horizontal",
    ticks=[6, 7, 8, 9],
)
cb.ax.tick_params(labelsize=10)

plt.plot(
    time_vector[earthquake_index_list],
    time_probability[earthquake_index_list],
    ".k",
    markersize=3,
    zorder=50,
)

plt.xlabel("time index")
plt.ylabel("probability")
plt.xlim([np.min(time_vector), np.max(time_vector)])
plt.ylim([1e-4, 1])
# plt.savefig("example_probability_time_series_semilogy.pdf")
# plt.savefig("example_probability_time_series_semilogy.png", dpi=500)
plt.show()

# Earthquake magnitude plot
plt.figure(figsize=(10, 3))
for i in range(len(earthquake_index_list)):
    plt.plot(
        [time_vector[earthquake_index_list[i]], time_vector[earthquake_index_list[i]]],
        [6.0, earthquake_magnitude_list[i]],
        "-",
        # markersize=10**(earthquake_magnitude_list[i] - 6),
        linewidth=0.25,
        zorder=10,
        color="k",
    )


cmap = cc.cm.CET_L17
magnitude_plot_size = 1e-5 * 10 ** np.array(earthquake_magnitude_list)
plt.scatter(
    time_vector[earthquake_index_list],
    earthquake_magnitude_list,
    s=magnitude_plot_size,
    c=earthquake_magnitude_list,
    zorder=20,
    alpha=0.65,
    cmap=cmap,
    edgecolors=None,
    linewidths=0.25,
    vmin=6.0,
    vmax=9.0,
)

# for i in range(len(earthquake_index_list)):
#     plt.plot(
#         time_vector[earthquake_index_list[i]],
#         earthquake_magnitude_list[i],
#         ".",
#         markersize=10 ** (earthquake_magnitude_list[i] - 6),
#         # markersize=10,
#         alpha=1.0,
#         linewidth=0.0,
#         zorder=20,
#         color="orange",
#         markeredgecolor="k",
#         markeredgewidth=0.25,
#     )
plt.xlabel("time index")
plt.ylabel("magnitude")
plt.xlim([np.min(time_vector), np.max(time_vector)])
# plt.ylim([6, 10])
# plt.grid(True, linewidth=0.5, linestyle="--")

# plt.savefig("example_magnitude_time_series_semilogy.pdf")
# plt.savefig("example_magnitude_time_series_semilogy.png", dpi=500)
plt.show()
# Out:
# /Users/meade/mambaforge/envs/skies/lib/python3.10/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
# def get_omori_decay_probability(time_vector, time_of_earthquake, amplitude, decay_time):
#     omori_decay_probability = amplitude / (
#         1 + (1 / decay_time) * (time_vector - time_of_earthquake)
#     )

#     omori_decay_probability[time_vector < time_of_earthquake] = 0.0
#     return omori_decay_probability


def get_omori_rate(time_vector, time_of_earthquake, productivity, decay_time, p):
    omori_rate = (
        productivity / (1 + (1 / decay_time) * (time_vector - time_of_earthquake)) ** p
    )
    omori_rate[time_vector < time_of_earthquake] = 0.0
    return omori_rate


def get_omori_productivity(
    moment_magnitude, amplitude_scale_factor, moment_magnitude_exponent
):
    omori_productivity = amplitude_scale_factor * (
        moment_magnitude**moment_magnitude_exponent
    )
    return omori_productivity


# def get_tanh_probability(x, amplitude_scale_factor, data_scale_factor):
#     tanh_probability = amplitude_scale_factor * np.tanh(data_scale_factor * x)
#     tanh_probability[np.where(x < 0.0)] = 0.0
#     tanh_probability[np.where(tanh_probability > 1.0)] = 1.0
#     return tanh_probability


n_years = 100
event_time = 20
event_moment_magnitude = 7.0

n_steps = 10000
time_index = np.linspace(0, n_years, n_steps)
event_moment = skies.moment_magnitude_to_moment(event_moment_magnitude)
loading_rate = event_moment / n_years

event_omori_productivity_amplitude_scale_factor = 0.1
event_omori_productivity_moment_magnitude_exponent = 1.0
event_omori_productivity = get_omori_productivity(
    event_moment_magnitude,
    event_omori_productivity_amplitude_scale_factor,
    event_omori_productivity_moment_magnitude_exponent,
)
event_omori_decay_time = 1.0
event_omori_exponent = 1.0
event_moment_omori_scaling = event_moment


# Loading response
ts_loading = loading_rate * time_index

# Raw Omori response
ts_omori = (
    2
    * event_moment_omori_scaling
    * get_omori_rate(
        time_index,
        event_time,
        event_omori_productivity,
        event_omori_decay_time,
        event_omori_exponent,
    )
)

# Moment deficit response
ts_eq = np.zeros_like(time_index)
ts_eq[np.where(time_index > event_time)] = -1 * event_moment

# Cumulative
ts_cumulative = ts_loading + ts_omori + ts_eq

# Probability
amplitude_scale_factor = 1e0
data_scale_factor = 1e-19
ts_probability = get_tanh_probability(
    ts_cumulative, amplitude_scale_factor, data_scale_factor
)


plt.figure(figsize=(16, 6))
n_rows = 2
n_cols = 3

plt.subplot(n_rows, n_cols, 1)
plt.plot(time_index, ts_loading, "r-")
plt.grid(True)
plt.title("loading")

plt.subplot(n_rows, n_cols, 2)
plt.plot(time_index, ts_omori, "r-")
plt.grid(True)
plt.title("Omori")

plt.subplot(n_rows, n_cols, 3)
plt.plot(time_index, ts_eq, "r-")
plt.grid(True)
plt.title("geometric moment")

plt.subplot(n_rows, n_cols, 4)
plt.plot(time_index, ts_cumulative, "r-")
plt.grid(True)
plt.title("cumulative")

plt.subplot(n_rows, n_cols, 6)
plt.plot(time_index, ts_probability, "r-")
plt.grid(True)
plt.title("probability")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 81
#      79 amplitude_scale_factor = 1e0
#      80 data_scale_factor = 1e-19
# ---> 81 ts_probability = get_tanh_probability(
#      82     ts_cumulative, amplitude_scale_factor, data_scale_factor
#      83 )
#      86 plt.figure(figsize=(16, 6))
#      87 n_rows = 2
#
# Cell In [5], line 79, in get_tanh_probability(x, amplitude_scale_factor, data_scale_factor)
#      77 def get_tanh_probability(x, amplitude_scale_factor, data_scale_factor):
#      78     tanh_probability = amplitude_scale_factor * np.tanh(data_scale_factor * x)
# ---> 79     if tanh_probability < 0:
#      80         tanh_probability = 0
#      81     if tanh_probability > 1:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
amplitude = 1.0
ots = get_omori_decay_probability(
    time_vector, 2000, amplitude, decay_time=100.0
)

ots[np.where(time_vector > 2000)] -= (amplitude / 2.0)

plt.figure()
plt.plot(time_vector, ots)
plt.show()
